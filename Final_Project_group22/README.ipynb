# %% [markdown]
# # TIL 6022 Final project group 22.
#
# This project is made by:
# Charlotte Koning,
# Cleo Vos,
# Koen Awater,
# Jasmijn van de Kar,
# Jippo Steenstra
#
# The repository contains:
#
# The report: Final_Project.ipynb
#
# The Proposal/code: Project_code.ipynb
#
# The data: under data folder
